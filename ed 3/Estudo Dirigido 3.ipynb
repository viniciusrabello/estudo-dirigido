# %% [markdown]
# ## Estudo Dirigido 3
#
# ###### Calculadora Matricial com Classes

# %% [markdown]
# ISSO AQUI AINDA NAO ESTA PRONTO

# %% [markdown]
# O QUE FALTA?
#
# Apresentar a lista de matrizes com a identificação das matrizes pelo seu TIPO, seu número de linhas e colunas, ou, alternativamente, por um nome dado pelo usuário quando de sua criação.
#
# Colocar um monte de TRY e EXCEPT, ele deve cobrar bastante disso

# %%
memoria = []
memoriaTS = []
memoriaTI = []

backup = []

class Matrizes():
    def __init__(self,matriz,memoria=memoria,memoriaTS = memoriaTS,memoriaTI= memoriaTI,a = ' '):
        self.matriz = matriz
        self.memoria = memoria
        Matrizes.Tipo(self)
    def Tipo(self):
        if TriangularInf(self.matriz):
            memoriaTI.append(self.matriz)
            a = memoriaTI
        if TriangularSup(self.matriz):
            memoriaTS.append(self.matriz)
            a  = memoriaTS
        else:
            memoria.append(self.matriz)
            a = memoria
    def Soma(self,TIPOMEMO):
        print("Escolha sua matriz da memoria para fazer a soma")
        print("(a contagem começa no 1)")
        for i in range(len(TIPOMEMO)):
            print(TIPOMEMO[i])
        x = int(input(": "))-1
        print("Voce esta somando essa matriz: ",self.matriz)
        print("Com essa outra matriz:         ",TIPOMEMO[x])
        a = self.matriz
        b = TIPOMEMO[x]
        try:
            if len(a[0]) == len(b[0]) and len(a) == len(b):
                Mat = []    
                for i in range(len(a)):
                    linha = []
                    for j in range(int(len(a[i]))):
                        linha.append(int(a[i][j]) + int(b[i][j]))
                    Mat.append(linha)
                print("Voce quer salvar o resultado na memória? ")
                h = input("(s para sim e n para nao): ")
                if h == 's':
                    Matrizes(Mat)
                return Mat
            else:
                print("Suas matrizes possuem tamanho diferente, impossivel somar")
        except:
            print("Ops... Algo deu errado, tente novamente")
    def Subtracao(self,TIPOMEMO):
        print("Escolha sua matriz da memoria para fazer a subtração")
        print("(a contagem começa no 1)")
        for i in range(len(TIPOMEMO)):
            print(TIPOMEMO[i])
        x = int(input(": "))-1
        print("Voce esta subtraindo essa matriz: ",self.matriz)
        print("Com essa outra matriz:            ",TIPOMEMO[x])
        a = self.matriz
        b = TIPOMEMO[x]
        try:
            if len(a[0]) == len(b[0]) and len(a) == len(b):
                Mat = []    
                for i in range(len(a)):
                    linha = []
                    for j in range(int(len(a[i]))):
                        linha.append(int(a[i][j]) - int(b[i][j]))
                    Mat.append(linha)
                print("Voce quer salvar o resultado na memória? ")
                h = input("(s para sim e n para nao): ")
                if h == 's':
                    Matrizes(Mat)
                return Mat
            else:
                print("Suas matrizes possuem tamanho diferente, impossivel subtrair")
        except:
            print("Matrizes possuem tamanho diferente, não é possivel subtrair")
    def Escalar(self):
        a = self.matriz
        print("Voce esta multiplicando essa matriz por escalar\n",self.matriz)
        b = int(input("Digite sua escalar: "))
        Mat = []    
        for i in range(len(a)):
            linha = []
            for j in range(int(len(a[i]))):
                linha.append(int(a[i][j]) * b)
            Mat.append(linha)
        print("Voce quer salvar o resultado na memória? ")
        h = input("(s para sim e n para nao): ")
        if h == 's':
            Matrizes(Mat)
        return Mat
    def MultMat(self,TIPOMEMO):
        A = self.matriz
        print("Escolha sua matriz da memoria para fazer a multiplicação")
        print("(a contagem começa no 1)")
        for i in range(len(TIPOMEMO)):
            print(TIPOMEMO[i])
        x = int(input(": "))-1
        B = TIPOMEMO[x]
        print("Voce esta multiplicando essa matriz: ",A)
        print("Com essa outra matriz:               ",TIPOMEMO[x])
        LinhasA = len(A)
        ColunasA = len(A[0])
        LinhasB = len(B)
        ColunasB = len(B[0])
        if ColunasA != LinhasB:
            print("Você nao pode multiplicar essas matrizes")
            return
        C = [[0 for lin in range(ColunasB)] for col in range(LinhasA)]
        for i in range(LinhasA):
            for j in range(ColunasB):
                for k in range(ColunasA):
                    C[i][j] += A[i][k] * B[k][j]
        print("Voce quer salvar o resultado na memória? ")
        h = input("(s para sim e n para nao): ")
        if h == 's':
            Matrizes(C)
        print(C)
    def Tranposicao(self):
        Mat = []
        a = self.matriz
        linhas = len(a)
        colunas = len(a[0])
        for i in range(colunas):
            linha = []
            for j in range(linhas):
                linha.append(a[j][i])
            Mat.append(linha)
        print(Mat)
        print("Voce quer salvar o resultado na memória? ")
        h = input("(s para sim e n para nao): ")
        if h == 's':
            Matrizes(Mat)
    def PrintarMemo(self):
        for i in range(len(a)):
            for j in range(len(a[i])):
                print(a[i][j])
            print("")


def TriangularInf(M): 
    for i in range(len(M)): 
        for j in range(i+1, len(M)): 
            if M[i][j] != 0:
                    #print("Sua matriz não é triangular inferior")
                    return False
    #print("Sua matriz é triangular inferior")
    return True

def identidade():
    n = int(input("Número de linhas e colunas: "))
    m=[[0 for x in range(n)] for y in range(n)]
    for i in range(0,n):
        m[i][i] = 1
    print(m)
    print("Voce quer salvar a identidade na memória? ")
    h = input("(s para sim e n para nao): ")
    if h == 's':
        Matrizes(m)

    
def Determinante(M):
    if TriangularInf(M):
        c = 1
        for i in range(0,len(M)):
            c *= M[i][i]
        print("Determinate = ",c)
    elif TriangularSup(M):
        c = 1
        for i in range(0,len(M)):
            c *= M[i][i]
        print("Determinate = ",c)
    else:
        print("\nOps...\nSua matriz não é triangular\nnão é possível calcular seu determinante")


def TriangularSup(M):
    for i in range(len(M)):
        for j in range(i):
            if M[i][j] != 0:
                #print("Sua matriz não é triangular superior\n")
                return False
    #print("Sua matriz é triangular superior\n")
    return True

def Traco(M):
    if len(M) == len(M[-1]):
        c = 0
        for i in range(0,len(M)):
            c += M[i][i]
        print("Sua matriz é quadrada")
        print("Traço = ",c)

def abrir(arq):
    l = []
    with open(arq, 'r') as f:
        for line in f:
            if len(line) > 0:
                l.append(list(map(int, line.split(','))))
    Matriz = Matrizes(l)


def Backup():
    for i in range(len(memoria)):
        backup.append(memoria[i])
    for i in range(len(memoriaTS)):
        backup.append(memoriaTS[i])
    for i in range(len(memoriaTI)):
        backup.append(memoriaTI[i])
    print("O seu Backup foi criado/atualizado ")
    return backup

def LerBackup():
    if len(backup) != 0:
        for i in range(len(backup)):
            print(backup[i])
    else:
        print("Seu Backup está vazio")
        

def ApagarBackup():
    h = input("Você tem certeza? (s para sim e n para não) ")
    if  h == 's':
        backup.clear()

def PrintarMemoria(a):
    for i in range(len(a)):
        for j in range(len(a[i])):
            print(a[i][j])
        print("")

def CriarMat():
    a = int(input("Número de linhas? "))
    b = int(input("Numero de colunas? "))
    matriz = []
    print("")
    c = 0
    for i in range (a):
        linha = [int(i) for i in input("Escreva sua linha separando-a por espaço: ").split()]
        matriz.append(linha)
        while len(linha) < b:
            linha.append(1)
        while len(linha) > b:
            del linha[-1] 
    Matrizes(matriz)
    return matriz

def VerMemoriaToda():
    print("")
    for i in range(len(memoria)):
        print(memoria[i])
        print("")
    for i in range(len(memoriaTI)):
        print(memoriaTI[i])
        print("")
    for i in range(len(memoriaTS)):
        print(memoriaTS[i])
        print("")

def AttMemoria():
    print("Você selecionou atualizar sua memoria com o Backup, isso vai destruir sua memoria atual.")
    dec = (input("Você tem certeza disso? (s para sim e n para não) ")).lower()
    if dec == 's':
        memoria.clear()
        for i in backup:
            if TriangularInf(i):
                memoriaTI.append(i)
            if TriangularSup():
                memoriaTS.append(i)
            else:
                memoria.append(i)
        VerMemoriaToda()
    elif dec == 'n':
        pass
    else:
        print("Você digitou algo diferente de n ou s, tente novamente")
        AttMemoria()
    return memoria

def Menu2():
    print("_____________________________________________")
    print("|               Menu 2                      |")
    print("|                                           |")
    print("|1. Apagar memória                          |")
    print("|2. Imprimir memória completa               |")
    print("|3. Tipo da matriz                          |")
    print("|4. Alterar uma matriz da memoria           |")
    print("|5. Atualizar/Criar Backup                  |")
    print("|6. Ver o Backup                            |")
    print("|7. Zerar Backup                            |")
    print("|8. Atualizar a memória com o Backup        |")
    print("|9. Não sei o que colocar aqui              |")
    print("|___________________________________________|")
    try: Opcao2 = int(input("Qual é sua escolha? "))
    except:
        print("\nOps...Algo deu errado\nTente novamente")
        Opcao2 = 0
    if Opcao2 == 1:
        print("Voce quer apagar todas as memorias? ")
        x = input("(s para sim e n para nao) ")
        if x == 's':
            memoriaTI.clear()
            memoriaTS.clear()
            memoria.clear()
        else:
            print("Voce quer apagar alguma memoria especifica? ")
            h = input("(s para sim e n para não) ")
            if h == 's':
                print("Qual das memórias?\n1-Matrizes quadradas\n2-Triangulares Superiores\n3-Triangulares Inferiores")
    if Opcao2 == 2:
        print("Memoria Quadrada\n_____________________________________________________________________________")
        PrintarMemoria(memoria)
        print("Memoria Triangular Inferior\n_____________________________________________________________________________")
        PrintarMemoria(memoriaTI)
        print("Memoria Triangular Superior\n_____________________________________________________________________________")
        PrintarMemoria(memoriaTS)
    if Opcao2 == 3:
        print("Vamos ver o tipo da matriz")
        VerMemoriaToda()
        print("Essas são as matrizes salvas")
        h = int(input("Digite qual que voce quer analisar: (contagem começa no 1)"))
        if h <= len(memoria):
            print("Quadrada")
        elif h <= len(memoriaTI)+len(memoria):
            print("Triangular inferior")
        elif h <= len(memoriaTI)+len(memoriaTS)+len(memoria):
            print("Triangular Superior")
    if Opcao2 == 4:
        print("Voce selecionou alterar uma matriz da memória\n")
        print("Qual das memórias?\n1-Matrizes quadradas\n2-Triangulares Superiores\n3-Triangulares Inferiores")
        f = int(input(": "))
        if f == 1:
            PrintarMemoria(memoria)
            print("Escolha qual que voce quer alterar ")
            O = int(input("(contagem comeca no 1)"))-1
            del memoria[O-1]
            CriarMat()
        if f == 2:
            PrintarMemoria(memoriaTS)
            print("Escolha qual que voce quer alterar ")
            O = int(input("(contagem comeca no 1)"))-1
            del memoriaTS[O-1]
            CriarMat()
        if f == 3:
            PrintarMemoria(memoriaTI)
            print("Escolha qual que voce quer alterar ")
            O = int(input("(contagem comeca no 1)"))-1
            del memoriaTI[O-1]
            CriarMat()
    if Opcao2 == 5:
        Backup()
    if Opcao2 == 6:
        LerBackup()
    if Opcao2 == 7:
        ApagarBackup()
    if Opcao2 == 8:
        AttMemoria()
    if Opcao2 == 9:
        print("________Não_sei_o_vou_colocar_aqui__________")

while True:
    print("_____________________________________________")
    print("|               Menu                        |")
    print("|                                           |")
    print("|1. Ler Matriz de um arquivo                |")
    print("|2. Criar Matriz identidade                 |")
    print("|3. Criar Nova Matriz                       |")
    print("|4. Determinate de matrizes triangulares    |")
    print("|5. Traço da matriz quadrada                |")
    print("|6. Operações com a memória                 |")
    print("|7.                                         |")
    print("|8. Transposição                            |")
    print("|9. Soma de matrizes                        |")
    print("|10. Subtração de matrizes                  |")
    print("|11. Multiplicação matricial                |")
    print("|12. Escalar                                |")
    print("|13. Sair do programa                       |")    
    print("|___________________________________________|")
    try: Opcao = int(input("Sua opção do menu: "))
    except: print("\nVocê não digitou nada...\nTente novamente")
    if Opcao == 1:
        x = input("Digite o seu arquivo com a extensão(txt,csv,etc...) ")
        abrir(x) 
    if Opcao == 2:
        identidade()
    if Opcao == 3:
        CriarMat()
    if Opcao == 4:
        h = input("Triangular inferior ou superior? (inf para inferior ou sup para superior) ")
        if h == 'inf':
            PrintarMemoria(memoriaTI)
            x = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            Determinante(memoriaTI[x])
        if h == 'sup':
            PrintarMemoria(memoriaTS)
            x = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            Determinante(memoriaTS[x])
    if Opcao == 5:
        print("1-Triangular Inferior\n2-Triangular Superior\n3-Quadrada\n")
        h = int(input(": "))
        if h == 1:
            PrintarMemoria(memoriaTI)
            x = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            Traco(memoriaTI[x])
        if h == 2:
            PrintarMemoria(memoriaTS)
            x = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            Traco(memoriaTS[x])
        if h == 3:
            PrintarMemoria(memoria)
            x = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            Traco(memoria[x])
    if Opcao == 6:
        Menu2()
    if Opcao == 7:
        print("Colocar alguma coisa aqui !")
    if Opcao == 8:
        print("Qual tipo de matrizes você quer realizar a operação")
        print("\n1-Triangular superior\n2-Triangular inferior\n3-Quadrada\n")
        x = int(input(":"))
        if x == 1:
            PrintarMemoria(memoriaTI)
            h = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            C = Matrizes(memoriaTI[h])
            del memoriaTI[-1]
            C.Tranposicao()
        if x == 2:
            PrintarMemoria(memoriaTS)
            h = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            C = Matrizes(memoriaTS[h])
            del memoriaTS[-1]
            C.Tranposicao()
        if x == 3:
            PrintarMemoria(memoria)
            h = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            C = Matrizes(memoria[h])
            del memoria[-1]
            C.Tranposicao()
    if Opcao == 9:
        print("Qual tipo de matrizes voce quer realizar a operação")
        print("\n1-Triangular superior\n2-Triangular inferior\n3-Quadrada\n")
        x = int(input(":"))
        if x == 1:
            PrintarMemoria(memoriaTI)
            h = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            C = Matrizes(memoriaTI[h])
            del memoriaTI[-1]
            C.Soma(memoriaTI)
        if x == 2:
            PrintarMemoria(memoriaTS)
            h = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            C = Matrizes(memoriaTS[h])
            del memoriaTS[-1]
            C.Soma(memoriaTS)
        if x == 3:
            PrintarMemoria(memoria)
            h = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            C = Matrizes(memoria[h])
            del memoria[-1]
            C.Soma(memoria)
    if Opcao == 10:
        print("Qual tipo de matrizes voce quer realizar a operação")
        print("\n1-Triangular superior\n2-Triangular inferior\n3-Quadrada\n")
        x = int(input(":"))
        if x == 1:
            PrintarMemoria(memoriaTI)
            h = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            C = Matrizes(memoriaTI[h])
            del memoriaTI[-1]
            C.Subtracao(memoriaTI)
        if x == 2:
            PrintarMemoria(memoriaTS)
            h = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            C = Matrizes(memoriaTS[h])
            del memoriaTS[-1]
            C.Subtracao(memoriaTS)
        if x == 3:
            PrintarMemoria(memoria)
            h = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            C = Matrizes(memoria[h])
            del memoria[-1]
            C.Subtracao(memoria)
    if Opcao == 11:
        print("Qual tipo de matrizes voce quer realizar a operação")
        print("\n1-Triangular superior\n2-Triangular inferior\n3-Quadrada\n")
        x = int(input(":"))
        if x == 1:
            PrintarMemoria(memoriaTI)
            h = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            C = Matrizes(memoriaTI[h])
            del memoriaTI[-1]
            C.MultMat(memoriaTI)
        if x == 2:
            PrintarMemoria(memoriaTS)
            h = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            C = Matrizes(memoriaTS[h])
            del memoriaTS[-1]
            C.MultMat(memoriaTS)
        if x == 3:
            PrintarMemoria(memoria)
            h = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            C = Matrizes(memoria[h])
            del memoria[-1]
            C.MultMat(memoria)
    if Opcao == 12:
        print("Qual tipo de matrizes voce quer realizar a operação")
        print("\n1-Triangular superior\n2-Triangular inferior\n3-Quadrada\n")
        x = int(input(":"))
        if x == 1:
            PrintarMemoria(memoriaTI)
            h = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            C = Matrizes(memoriaTI[h])
            del memoriaTI[-1]
            C.Escalar()
        if x == 2:
            PrintarMemoria(memoriaTS)
            h = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            C = Matrizes(memoriaTS[h])
            del memoriaTS[-1]
            C.Escalar()
        if x == 3:
            PrintarMemoria(memoria)
            h = int(input("Escolha a matriz da memória: (contagem comeca no 1) "))-1
            C = Matrizes(memoria[h])
            del memoria[-1]
            C.Escalar()    
    if Opcao == 13:
        print("Voce saiu do programa!")
        break
# Out:
# _____________________________________________
# |               Menu                        |
# |                                           |
# |1. Ler Matriz de um arquivo                |
# |2. Criar Matriz identidade                 |
# |3. Criar Nova Matriz                       |
# |4. Determinate de matrizes triangulares    |
# |5. Traço da matriz quadrada                |
# |6. Operações com a memória                 |
# |7.                                         |
# |8. Transposição                            |
# |9. Soma de matrizes                        |
# |10. Subtração de matrizes                  |
# |11. Multiplicação matricial                |
# |12. Escalar                                |
# |13. Sair do programa                       |
# |___________________________________________|
# Sua opção do menu: 3
# Número de linhas? 3
# Numero de colunas? 3
#
# Escreva sua linha separando-a por espaço: 1 3 4
# Escreva sua linha separando-a por espaço: 5 6 6
# ...
